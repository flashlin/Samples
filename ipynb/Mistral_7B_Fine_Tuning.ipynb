# %% [markdown]
# LIB CREDITS 1:
# https://twitter.com/abhi1thakur
#
# CODE & DATASET CREDITS 2: https://twitter.com/@josh_bickett

# %%
# !nvidia-smi
# Out:
# Fri Sep 29 20:16:59 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Fine-tuning Mistral 7b with AutoTrain
#
# In this notebook, we'll walk you through the steps to fine-tune Mistral 7b using your dataset.
# Follow along by running each cell in order!

# %% [markdown]
# ### Setup Runtime
# For fine-tuning Llama, a GPU instance is essential. Follow the directions below:
#
# 1. Go to `Runtime` (located in the top menu bar).
# 2. Select `Change Runtime Type`.
# 3. Choose `T4 GPU` (or a comparable option).

# %% [markdown]
# ### Package Installation
#
# Before we get started, let's ensure we have all the necessary packages installed.

# %%
# !pip install -q pandas

# %%
# !pip install -q autotrain-advanced

# %% [markdown]
# ### Setup Autotrain
# The step below is required for AutoTrain in Colab

# %%
# !autotrain setup --update-torch
# Out:
# > INFO    Installing latest transformers@main
# > INFO    Successfully installed latest transformers
# > INFO    Installing latest peft@main
# > INFO    Successfully installed latest peft
# > INFO    Installing latest diffusers@main
# > INFO    Successfully installed latest diffusers
# > INFO    Installing latest trl@main
# > INFO    Successfully installed latest trl
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch

# %% [markdown]
# ### Connect to Hugging Face for model upload
# #### Logging to Hugging Face
#
# To make sure the model can be uploaded to be used for Inference, it's necessary to log in to the Hugging Face hub.
#
# #### Getting a Hugging Face token
# Steps:
# 1. Navigate to this URL: https://huggingface.co/settings/tokens
# 2. Create a `write` token and copy it to your clipboard
# 3. Run the code below and enter your token

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### Upload your dataset
# Add your data set to the root directory in the Colab under the name `train.csv`. The AutoTrain command will look for your data there under that name.
#
# ##### Don't have a data set and want to try finetuning on an example data set?
# If you don't have a dataset you can run these commands below to get an example data set and save it to `train.csv`

# %%
# !git clone https://github.com/joshbickett/finetune-llama-2.git
# %cd finetune-llama-2
# %mv train.csv ../train.csv
# %cd ..

# %%
import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#                            Concept  \
# 0       A person walks in the rain
# 1            A cat chasing a mouse
# 2              A dog eating a bone
# 3         A bird flying in the sky
# 4        A fish swimming in a tank
# 5        A child playing with toys
# 6        A car driving on the road
# 7    A flower blooming in a garden
# 8          A bee collecting pollen
# 9     A sun setting over the ocean
# 10        A cow grazing in a field
# 11       A snail racing on a track
# 12        A penguin sliding on ice
# 13    A lion roaring in the jungle
# 14     A monkey swinging on a tree
# 15   A turtle sunbathing on a rock
# 16    A rabbit hopping in a meadow
# 17      A squirrel collecting nuts
# 18      A wolf howling at the moon
# 19     A fox sneaking in the woods
# 20       A bear fishing in a river
# 21       A hippo bathing in a pond
# 22    A giraffe eating from a tree
# 23      An elephant spraying water
# 24  A kangaroo jumping in a desert
#
#                              Funny Description Prompt  \
# 0   A person walks in the rain, wearing a suit mad...
# 1   A cat, wearing detective attire and sunglasses...
# 2   A dog with a chef's hat is eating a bone seaso...
# 3   A bird with oversized sunglasses and a basebal...
# 4   A fish in a snorkel and flippers swimming in a...
# 5   A child in a superhero cape playing with alien...
# 6   A car with legs instead of wheels running down...
# 7   A flower wearing a top hat and bow tie bloomin...
# 8   A bee with a backpack vacuum cleaner collectin...
# 9   The sun wearing sunglasses and sipping on a tr...
# 10  A cow with headphones on, jamming to music whi...
# 11  A snail with a racing helmet and number '1' pa...
# 12  A penguin in ice skates, doing figure skating ...
# 13  A lion with a microphone, singing a ballad in ...
# 14  A monkey in a trapeze artist outfit, swinging ...
# 15  A turtle with sunglasses on, sunbathing on a r...
# 16  A rabbit in basketball attire, hopping around ...
# 17  A squirrel in a miner's helmet, using a drill ...
# 18  A wolf in pajamas, howling at the moon, with a...
# 19  A fox in ninja attire, sneaking around the woo...
# 20  A bear with a fishing rod and a fisherman's ha...
# 21  A hippo with a shower cap on, using a giant ru...
# 22  A giraffe with a long scarf, eating from a tre...
# 23  An elephant with a water gun, having a water f...
# 24  A kangaroo with spring shoes, jumping around i...
#
#                                                  text
# 0   ###Human:\ngenerate a midjourney prompt for A ...
# 1   ###Human:\ngenerate a midjourney prompt for A ...
# 2   ###Human:\ngenerate a midjourney prompt for A ...
# 3   ###Human:\ngenerate a midjourney prompt for A ...
# 4   ###Human:\ngenerate a midjourney prompt for A ...
# 5   ###Human:\ngenerate a midjourney prompt for A ...
# 6   ###Human:\ngenerate a midjourney prompt for A ...
# 7   ###Human:\ngenerate a midjourney prompt for A ...
# 8   ###Human:\ngenerate a midjourney prompt for A ...
# 9   ###Human:\ngenerate a midjourney prompt for A ...
# 10  ###Human:\ngenerate a midjourney prompt for A ...
# 11  ###Human:\ngenerate a midjourney prompt for A ...
# 12  ###Human:\ngenerate a midjourney prompt for A ...
# 13  ###Human:\ngenerate a midjourney prompt for A ...
# 14  ###Human:\ngenerate a midjourney prompt for A ...
# 15  ###Human:\ngenerate a midjourney prompt for A ...
# 16  ###Human:\ngenerate a midjourney prompt for A ...
# 17  ###Human:\ngenerate a midjourney prompt for A ...
# 18  ###Human:\ngenerate a midjourney prompt for A ...
# 19  ###Human:\ngenerate a midjourney prompt for A ...
# 20  ###Human:\ngenerate a midjourney prompt for A ...
# 21  ###Human:\ngenerate a midjourney prompt for A ...
# 22  ###Human:\ngenerate a midjourney prompt for A ...
# 23  ###Human:\ngenerate a midjourney prompt for An...
# 24  ###Human:\ngenerate a midjourney prompt for A ...

# %%
df['text'][13]
# Out:
# '###Human:\ngenerate a midjourney prompt for A lion roaring in the jungle\n\n###Assistant:\nA lion with a microphone, singing a ballad in the jungle with a group of birds as backup singers.'

# %% [markdown]
# ## Overview of AutoTrain command
#
# #### Short overview of what the command flags do.
#
# - `!autotrain`: Command executed in environments like a Jupyter notebook to run shell commands directly. `autotrain` is an automatic training utility.
#
# - `llm`: A sub-command or argument specifying the type of task
#
# - `--train`: Initiates the training process.
#
# - `--project_name`: Sets the name of the project
#
# - `--model abhishek/llama-2-7b-hf-small-shards`: Specifies original model that is hosted on Hugging Face named "llama-2-7b-hf-small-shards" under the "abhishek".
#
# - `--data_path .`: The path to the dataset for training. The "." refers to the current directory. The `train.csv` file needs to be located in this directory.
#
# - `--use_int4`: Use of INT4 quantization to reduce model size and speed up inference times at the cost of some precision.
#
# - `--learning_rate 2e-4`: Sets the learning rate for training to 0.0002.
#
# - `--train_batch_size 12`: Sets the batch size for training to 12.
#
# - `--num_train_epochs 3`: The training process will iterate over the dataset 3 times.
#
# ### Steps needed before running
# Go to the `!autotrain` code cell below and update it by following the steps below:
#
# 1. After `--project_name` replace `*enter-a-project-name*` with the name that you'd like to call the project
# 2. After `--repo_id` replace `*username*/*repository*`. Replace `*username*` with your Hugging Face username and `*repository*` with the repository name you'd like it to be created under. You don't need to create this repository before hand, it will automatically be created and uploaded once the training is completed.
# 3. Confirm that `train.csv` is in the root directory in the Colab. The `--data_path .` flag will make it so that AutoTrain looks for your data there.
# 4. Make sure to add the LoRA Target Modules to be trained `--target-modules q_proj, v_proj`
# 5. Once you've made these changes you're all set, run the command below!

# %%
# !autotrain llm --train --project_name mistral-7b-mj-finetuned --model bn22/Mistral-7B-Instruct-v0.1-sharded --data_path . --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 12 --num_train_epochs 3 --trainer sft --target_modules q_proj,v_proj --push_to_hub --repo_id 1littlecoder/mistral-7b-mj-finetuned
# Out:
# > INFO    Running LLM
# > INFO    Params: Namespace(version=False, train=True, deploy=False, inference=False, data_path='.', train_split='train', valid_split=None, text_column='text', model='bn22/Mistral-7B-Instruct-v0.1-sharded', learning_rate=0.0002, num_train_epochs=3, train_batch_size=12, warmup_ratio=0.1, gradient_accumulation_steps=1, optimizer='adamw_torch', scheduler='linear', weight_decay=0.0, max_grad_norm=1.0, seed=42, add_eos_token=False, block_size=-1, use_peft=True, lora_r=16, lora_alpha=32, lora_dropout=0.05, logging_steps=-1, project_name='mistral-7b-mj-finetuned', evaluation_strategy='epoch', save_total_limit=1, save_strategy='epoch', auto_find_batch_size=False, fp16=False, push_to_hub=True, use_int8=False, model_max_length=1024, repo_id='1littlecoder/mistral-7b-mj-finetuned', use_int4=True, trainer='sft', target_modules='q_proj,v_proj', merge_adapter=False, token=None, backend='default', username=None, use_flash_attention_2=False, func=<function run_llm_command_factory at 0x7f8056d49870>)
# > INFO    loading dataset from csv
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Using pad_token, but it is not set yet.
# Loading checkpoint shards: 100% 11/11 [01:36<00:00,  8.75s/it]
# Downloading (…)neration_config.json: 100% 116/116 [00:00<00:00, 695kB/s]
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 32000. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# > INFO    creating trainer
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:214: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
#   0% 0/9 [00:00<?, ?it/s]You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 1.4339, 'learning_rate': 0.0002, 'epoch': 0.33}
# {'loss': 1.4339, 'learning_rate': 0.000175, 'epoch': 1.33}
# {'loss': 1.2696, 'learning_rate': 0.00015000000000000001, 'epoch': 2.33}
# {'train_runtime': 41.4563, 'train_samples_per_second': 1.809, 'train_steps_per_second': 0.217, 'train_loss': 1.3791579405466716, 'epoch': 2.33}
#  33% 3/9 [00:41<01:22, 13.82s/it]
# > INFO    Finished training, saving model...
# > INFO    Pushing model to hub...
# adapter_model.bin:   0% 0.00/27.3M [00:00<?, ?B/s]
# optimizer.pt:   0% 0.00/54.6M [00:00<?, ?B/s]
#
# adapter_model.bin:   0% 0.00/27.3M [00:00<?, ?B/s]
#
#
#
# rng_state.pth:   0% 0.00/14.6k [00:00<?, ?B/s]
#
#
# Upload 10 LFS files:   0% 0/10 [00:00<?, ?it/s]
#
#
#
#
# adapter_model.bin:   0% 16.4k/27.3M [00:00<20:48, 21.9kB/s]
# optimizer.pt:   0% 16.4k/54.6M [00:00<43:17, 21.0kB/s]
#
# adapter_model.bin:   0% 16.4k/27.3M [00:00<21:55, 20.7kB/s]
#
#
#
#
# scheduler.pt: 100% 627/627 [00:00<00:00, 792B/s]
#
#
#
# adapter_model.bin:   2% 524k/27.3M [00:00<00:33, 810kB/s]
# optimizer.pt:   1% 475k/54.6M [00:00<01:16, 711kB/s]
#
# scheduler.pt: 100% 627/627 [00:00<00:00, 666B/s]
# adapter_model.bin:  15% 4.16M/27.3M [00:00<00:03, 7.03MB/s]
# rng_state.pth: 100% 14.6k/14.6k [00:00<00:00, 14.7kB/s]
#
#
# adapter_model.bin:  33% 9.09M/27.3M [00:01<00:01, 15.1MB/s]
# optimizer.pt:  14% 7.44M/54.6M [00:01<00:04, 11.6MB/s]
#
# adapter_model.bin:  54% 14.9M/27.3M [00:01<00:00, 24.4MB/s]
# optimizer.pt:  23% 12.5M/54.6M [00:01<00:02, 18.8MB/s]
#
# adapter_model.bin:  68% 18.6M/27.3M [00:01<00:00, 23.1MB/s]
# adapter_model.bin:  93% 25.4M/27.3M [00:01<00:00, 31.7MB/s]
#
#
#
# tokenizer.model:   0% 0.00/493k [00:00<?, ?B/s]
#
#
#
#
# training_args.bin:   0% 0.00/4.09k [00:00<?, ?B/s]
#
# adapter_model.bin:  62% 17.0M/27.3M [00:01<00:00, 16.9MB/s]
# training_args.bin: 100% 4.09k/4.09k [00:00<00:00, 50.1kB/s]
#
#
#
#
# tokenizer.model:  33% 164k/493k [00:00<00:00, 1.46MB/s]
#
# adapter_model.bin:  86% 23.4M/27.3M [00:01<00:00, 25.1MB/s]
# adapter_model.bin: 100% 27.3M/27.3M [00:01<00:00, 15.7MB/s]
# events.out.tfevents.1696019621.7db06c960e6d.8931.0: 100% 5.34k/5.34k [00:00<00:00, 96.2kB/s]
#
# tokenizer.model: 100% 493k/493k [00:00<00:00, 1.24MB/s]
#
# adapter_model.bin: 100% 27.3M/27.3M [00:01<00:00, 13.8MB/s]
# tokenizer.model:   0% 0.00/493k [00:00<?, ?B/s]
# optimizer.pt:  88% 48.3M/54.6M [00:02<00:00, 35.4MB/s]
#
#
# Upload 10 LFS files:  10% 1/10 [00:02<00:19,  2.15s/it]
#
# training_args.bin: 100% 4.09k/4.09k [00:00<00:00, 34.0kB/s]
#
#
#
# optimizer.pt: 100% 54.6M/54.6M [00:02<00:00, 23.2MB/s]
# tokenizer.model: 100% 493k/493k [00:00<00:00, 1.51MB/s]
#
#
#
# Upload 10 LFS files: 100% 10/10 [00:02<00:00,  3.79it/s]

# %% [markdown]
# ## Completed 🎉
# After the command above is completed your Model will be uploaded to Hugging Face.
#
# #### Learn more about AutoTrain (optional)
# If you want to learn more about what command-line flags are available

# %%
# !autotrain llm -h

# %%
# !pip install -q safetensors

# %%
import torch
from peft import PeftModel
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "bn22/Mistral-7B-Instruct-v0.1-sharded"
#adapters_name = "1littlecoder/mistral-7b-mj-finetune"

device = "cuda" # the device to load the model onto

model = AutoModelForCausalLM.from_pretrained(
    model_name,
   # load_in_4bit=True,
    torch_dtype=torch.bfloat16,
    device_map='auto'
)
##model = PeftModel.from_pretrained(model, adapters_name)
#model = model.merge_and_unload()
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.bos_token_id = 1

stop_token_ids = [0]

print(f"Successfully loaded the model {model_name} into memory")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/11 [00:00<?, ?it/s]
# Downloading (…)l_00001-of-00010.bin:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-52b2d2e382c4> in <cell line: 10>()
#       8 device = "cuda" # the device to load the model onto
#       9
# ---> 10 model = AutoModelForCausalLM.from_pretrained(
#      11     model_name,
#      12    # load_in_4bit=True,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569         elif type(config) in cls._model_mapping.keys():
#     570             model_class = _get_model_class(config, cls._model_mapping)
# --> 571             return model_class.from_pretrained(
#     572                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2992         if is_sharded:
#    2993             # rsolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 2994             resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    2995                 pretrained_model_name_or_path,
#    2996                 resolved_archive_file,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1038         try:
#    1039             # Load from URL
# -> 1040             cached_filename = cached_file(
#    1041                 pretrained_model_name_or_path,
#    1042                 shard_filename,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     427     try:
#     428         # Load from URL or cache if already cached
# --> 429         resolved_file = hf_hub_download(
#     430             path_or_repo_id,
#     431             filename,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1362             logger.info("downloading %s to %s", url, temp_file.name)
#    1363
# -> 1364             http_get(
#    1365                 url_to_download,
#    1366                 temp_file,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries, expected_size)
#     539         disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     540     )
# --> 541     for chunk in r.iter_content(chunk_size=10 * 1024 * 1024):
#     542         if chunk:  # filter out keep-alive new chunks
#     543             progress.update(len(chunk))
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     938         else:
#     939             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 940                 data = self.read(amt=amt, decode_content=decode_content)
#     941
#     942                 if data:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     877                 return self._decoded_buffer.get(amt)
#     878
# --> 879         data = self._raw_read(amt)
#     880
#     881         flush_decoder = False
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _raw_read(self, amt)
#     812
#     813         with self._error_catcher():
# --> 814             data = self._fp_read(amt) if not fp_closed else b""
#     815             if amt is not None and amt != 0 and not data:
#     816                 # Platform-specific: Buggy versions of Python.
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _fp_read(self, amt)
#     797         else:
#     798             # StringIO doesn't like amt=None
# --> 799             return self._fp.read(amt) if amt is not None else self._fp.read()
#     800
#     801     def _raw_read(
#
# /usr/lib/python3.10/http/client.py in read(self, amt)
#     464                 # clip the read to the "end of response"
#     465                 amt = self.length
# --> 466             s = self.fp.read(amt)
#     467             if not s and amt:
#     468                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1272                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273                   self.__class__)
# -> 1274             return self.read(nbytes, buffer)
#    1275         else:
#    1276             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1128         try:
#    1129             if buffer is not None:
# -> 1130                 return self._sslobj.read(len, buffer)
#    1131             else:
#    1132                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
text = "<s>[INST] What is your favourite condiment? [/INST]"
"Well, I'm quite partial to a good squeeze of fresh lemon juice. It adds just the right amount of zesty flavour to whatever I'm cooking up in the kitchen!</s> "
"[INST] Do you have mayonnaise recipes? [/INST]"

encodeds = tokenizer(text, return_tensors="pt", add_special_tokens=False)

model_inputs = encodeds.to(device)
model.to(device)

generated_ids = model.generate(**model_inputs, max_new_tokens=1000, do_sample=True)
decoded = tokenizer.batch_decode(generated_ids)
print(decoded[0])
